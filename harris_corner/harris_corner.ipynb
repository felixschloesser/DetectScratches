# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from scipy.ndimage import filters
import sys
sys.path.append("/home/tintin/rongheng/cv/")
from imtools import load_img, show_img
from edge_detection import harris_response, get_points, overlay_points

# %%
plt.style.use('dark_background')

# %%
img = load_img("bearing_scrached_fuji_tunnel.jpg")

# %%
response = harris_response(img, sigma=2)
show_img(response, color=True)

points = get_points(response, min_dist = 8, threshold_percent = 0.07)
overlay_points(img, points, size=(20,20))
